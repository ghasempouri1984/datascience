# %%
# !pip install rdflib
from rdflib import Graph, URIRef, RDF, Namespace, Literal
from rdflib.namespace import XSD, RDFS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdflib
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      |████████████████████████████████| 482 kB 4.5 MB/s
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 301 kB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib) (57.4.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib) (4.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib) (1.15.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-6.1.1

# %%
from rdflib import Graph, URIRef, RDF, Namespace, Literal, BNode
from rdflib.namespace import XSD, RDFS
import pandas as pd
import json
from pprint import pprint
from json import load


my_graph = Graph()

# %%
# Define namespaces used
FABIO = Namespace("http://purl.org/spar/fabio/")
PRISM = Namespace("http://prismstandard.org/namespaces/basic/2.0/")
RES = Namespace("https://allorapy.github.io/res/")
CITO = Namespace("http://purl.org/spar/cito/")
DATACITE = Namespace("http://purl.org/spar/datacite/")
DCTERMS = Namespace("http://purl.org/dc/terms/")
FOAF = Namespace("http://xmlns.com/foaf/0.1/")
SCHEMA = Namespace("https://schema.org/")
WD = Namespace("http://widata.org/entity/")

my_graph.bind('fabio', FABIO)
my_graph.bind('prism', PRISM)
my_graph.bind('wd', WD)
my_graph.bind('', RES)

# classes of resources
JournalArticle = URIRef("http://purl.org/spar/fabio/JournalArticle")
BookChapter = URIRef("http://purl.org/spar/fabio/BookChapter")
ProceedingsPaper = URIRef("http://purl.org/spar/fabio/ProceedingsPaper")
Journal = URIRef("http://purl.org/spar/fabio/Journal")
Book = URIRef("https://schema.org/Book")
Proceedings = URIRef("http://purl.org/spar/fabio/ConferenceProceedings")
Publication = URIRef("https://www.wikidata.org/wiki/Q732577")
Venue = URIRef("https://www.wikidata.org/wiki/Q2085381")
Organization = URIRef("https://schema.org/Organization")
Person = URIRef("http://xmlns.com/foaf/0.1/Person")
IdentifiableEntity = URIRef("https://www.wikidata.org/wiki/Q35120")

# attributes related to classes
issue = URIRef("http://prismstandard.org/namespaces/basic/2.0/issueIdentifier")
volume = URIRef("http://purl.org/spar/fabio/JournalVolume")
chapterNumber = URIRef("http://purl.org/spar/fabio/hasSequenceIdentifier")
event = URIRef("https://schema.org/Event")
publicationYear = URIRef("http://purl.org/spar/fabio/hasPublicationYear")
title = URIRef("http://purl.org/dc/terms/title")
givenName = URIRef("http://xmlns.com/foaf/0.1/givenName")
familyName = URIRef("http://xmlns.com/foaf/0.1/familyName")
id = URIRef("https://schema.org/identifier")
doi = URIRef ("http://prismstandard.org/namespaces/basic/2.0/doi") # sub-property of http://purl.org/dc/terms/identifier --> see https://sparontologies.github.io/fabio/current/fabio.html#d4e1044

# relations among classes
cites = URIRef("https://schema.org/citation")
publicationVenue = URIRef("https://schema.org/isPartOf")
author = URIRef("http://purl.org/dc/terms/creator")
publisher = URIRef("http://purl.org/dc/terms/publisher")

# This is the string defining the base URL used to defined
# the URLs of all the resources created from the data
base_url = "https://allorapy.github.io/res/"

# %%
# importing authors from JSON

with open("/content/drive/MyDrive/Colab Notebooks/graph_other_data.json", "r", encoding="utf-8") as f:
    json_doc = load(f)
print(type(json_doc))

# read just authors

authors = json_doc["authors"]

# create the dataframe from json

df_authors=pd.DataFrame(authors.items(),columns=['doi','author']).explode('author')

df_person=pd.json_normalize(json.loads(df_authors.to_json(orient="records")))
df_person.rename(columns={"author.family":"family_name","author.given":"given_name","author.orcid":"orc_id"}, inplace = True)

df_person=pd.DataFrame(df_person)

# Remove "doi:" from DOI
#doi = ["doi:", "DOI:"]

#for char in doi:
  #df_person['doi'] = df_person['doi'].str.replace(char,"")

#df_person['doi'] = df_person['doi'].str.split().str.join("")

#getPublicationAuthors --> by the way it should be programmed as method 
#in order to use in Class 

#x = df[1][0]
#authors= pd.DataFrame.from_dict(x, orient='index')
#authors = authors.T

#a=pd.DataFrame(authors['doi:10.1162/qss_a_00023'])

#for raw in a.index:
#  if a['doi:10.1162/qss_a_00023'][raw]!=None:
#    print(a['doi:10.1162/qss_a_00023'][raw])



person_internal_id = {}

for idx, row in df_person.iterrows():
    local_id = "person-" + str(idx)

    # The shape of the new resources that are people is
    # 'https://allorapy.github.io/res/person-<integer>'
    subj = URIRef(base_url + local_id)

    # We put the new person resources created here, to use them
    # when creating publications
    #person_internal_id[row["doi"]] = subj

# più che creare un dict dovrei associare ad ogni doi i diversi autori (chiave con più valori)
# e poi passare la lista di valori (url) a publications - trovare soluzione

    #person_internal_id[row["doi"]] = list()
    #person_internal_id[row["doi"]].append(local_id)

    if local_id not in person_internal_id:
        person_internal_id[row["doi"]] = list()
    elif isinstance(person_internal_id[row["doi"]], list):
        person_internal_id[row["doi"]].append(local_id)
    else:
        person_internal_id[row["doi"]] = person_internal_id[row["doi"]], [local_id]

    my_graph.add((subj, RDF.type, Person))

    my_graph.add((subj, FOAF["familyName"], Literal(row["family_name"])))
    my_graph.add((subj, FOAF["givenName"], Literal(row["given_name"])))

print(person_internal_id)

df_person


#print(my_graph.serialize(format="turtle"))
# Out:
# <class 'dict'>
# {'doi:10.1016/j.websem.2021.100655': [], 'doi:10.1007/s10115-017-1100-y': [], 'doi:10.1016/j.websem.2014.03.003': [], 'doi:10.1093/nar/gkz997': [], 'doi:10.3390/publications7030050': [], 'doi:10.1017/s0269888920000065': [], 'doi:10.3390/info11030129': [], 'doi:10.1007/s00778-018-0528-3': [], 'doi:10.21105/joss.02731': [], 'doi:10.1016/j.websem.2014.06.002': [], 'doi:10.1007/s10115-019-01401-x': [], 'doi:10.1007/978-3-030-30793-6_22': [], 'doi:10.1007/978-3-030-33220-4_25': [], 'doi:10.1080/17538947.2020.1738568': [], 'doi:10.1007/s10462-020-09826-5': [], 'doi:10.1007/978-3-030-49461-2_25': [], 'doi:10.1007/s10462-020-09866-x': [], 'doi:10.1007/s10796-020-10035-2': [], 'doi:10.1007/978-3-030-60276-5_25': [], 'doi:10.1007/978-3-030-54956-5_2': [], 'doi:10.1007/s11280-020-00836-5': [], 'doi:10.3390/a13090217': [], 'doi:10.1007/978-3-030-62466-8_1': [], 'doi:10.1016/j.eswa.2020.113205': [], 'doi:10.1007/s00521-020-05491-5': [], 'doi:10.1002/bse.2855': [], 'doi:10.3390/info12040160': [], 'doi:10.1002/widm.1412': [], 'doi:10.3390/info12070271': [], 'doi:10.1108/dta-12-2020-0312': [], 'doi:10.1007/978-3-030-80418-3_17': [], 'doi:10.1007/978-3-030-82147-0_16': [], 'doi:10.1016/j.knosys.2021.107626': [], 'doi:10.1007/s10791-021-09398-0': [], 'doi:10.1016/j.websem.2021.100681': [], 'doi:10.1155/2014/506740': [], 'doi:10.1007/s10845-018-1427-6': [], 'doi:10.1080/20964471.2019.1661662': [], 'doi:10.3390/electronics7120371': [], 'doi:10.1080/19401493.2018.1492020': [], 'doi:10.3233/ds-170010': [], 'doi:10.4018/ijossp.2019040101': [], 'doi:10.4018/ijpada.2014010107': [], 'doi:10.4018/ijsita.2017100105': [], 'doi:10.4018/jdsst.2011010102': [], 'doi:10.4028/www.scientific.net/amm.809-810.1281': [], 'doi:10.1007/s41870-019-00283-0': [], 'doi:10.1177/2055207618804927': [], 'doi:10.1007/s12136-018-0370-7': [], 'doi:10.1007/s12145-019-00398-9': [], 'doi:10.1007/978-3-319-91189-2_11': [], 'doi:10.4258/hir.2018.24.4.376': [], 'doi:10.1155/2015/734984': [], 'doi:10.1186/s41039-019-0105-4': [], 'doi:10.1186/s41239-019-0146-1': [], 'doi:10.1007/978-3-030-00940-3_15': [], 'doi:10.1007/978-3-030-00940-3_6': [], 'doi:10.3390/app9122553': [], 'doi:10.1590/1981-5344/3306': [], 'doi:10.1007/s00530-019-00610-2': [], 'doi:10.1002/cpe.4489': [], 'doi:10.1111/exsy.12291': [], 'doi:10.1111/exsy.12355': [], 'doi:10.1111/exsy.12378': [], 'doi:10.1111/exsy.12380': [], 'doi:10.3390/ijgi6120386': [], 'doi:10.1111/cgf.13324': [], 'doi:10.1007/978-3-030-69992-5_1': [], 'doi:10.1007/978-3-658-33466-6_32': [], 'doi:10.1016/j.inffus.2021.01.007': [], 'doi:10.3390/ijgi10060358': [], 'doi:10.1007/978-3-030-71292-1_39': [], 'doi:10.3390/en14072024': [], 'doi:10.1016/j.compind.2021.103496': [], 'doi:10.1186/s13174-021-00135-w': [], 'doi:10.1080/15230406.2021.1952109': [], 'doi:10.1007/978-3-030-86970-0_23': [], 'doi:10.1017/s0269888921000114': [], 'doi:10.1016/j.jcp.2021.110624': [], 'doi:10.1007/978-3-030-82430-3_7': [], 'doi:10.1016/j.cageo.2021.105005': [], 'doi:10.3390/su132413844': [], 'doi:10.1108/oir-11-2020-0497': [], 'doi:10.3390/electronics10212616': [], 'doi:10.3390/app11219825': [], 'doi:10.3390/en14206692': [], 'doi:10.1080/00207543.2021.2002967': [], 'doi:10.3390/app12010143': [], 'doi:10.1007/978-3-030-89811-3_20': [], 'doi:10.1016/j.is.2021.101967': [], 'doi:10.3390/app12010287': [], 'doi:10.4018/978-1-6684-3702-5.ch037': [], 'doi:10.1016/j.eswa.2019.04.009': [], 'doi:10.1016/j.eswa.2019.112965': [], 'doi:10.1016/j.jss.2018.09.069': [], 'doi:10.1007/s10010-021-00466-x': [], 'doi:10.3390/info12060236': [], 'doi:10.3390/app11062813': [], 'doi:10.1007/s40194-021-01151-x': [], 'doi:10.1007/978-3-030-67708-4_5': [], 'doi:10.1016/j.comcom.2021.04.024': [], 'doi:10.1007/978-3-030-80847-1_9': [], 'doi:10.1080/0194262x.2021.1920555': [], 'doi:10.7466/jfbl.2020.38.4.1': [], 'doi:10.3390/jrfm14060238': [], 'doi:10.4018/978-1-7998-6792-0.ch005': [], 'doi:10.1111/exsy.12748': [], 'doi:10.3390/ani11010145': [], 'doi:10.3390/axioms10020093': [], 'doi:10.4018/978-1-7998-6874- ...
#                                    doi     family_name given_name  \
# 0     doi:10.1016/j.websem.2021.100655  Espinoza-Arias      Paola
# 1     doi:10.1016/j.websem.2021.100655          Garijo     Daniel
# 2     doi:10.1016/j.websem.2021.100655          Corcho      Oscar
# 3        doi:10.1007/s10115-017-1100-y      Diefenbach     Dennis
# 4     doi:10.1016/j.websem.2014.03.003           Groth       Paul
# ...                                ...             ...        ...
# 1427               doi:10.1145/3309547            Wang      Xiang
# 1428  doi:10.1007/978-3-030-58285-2_27          Martin       Leon
# 1429  doi:10.1007/978-3-030-58285-2_27       Boockmann     Jan H.
# 1430  doi:10.1007/978-3-030-58285-2_27         Henrich    Andreas
# 1431    doi:10.1007/s11280-020-00842-7              Li        Lin
#
#                    orc_id
# 0     0000-0002-3938-2064
# 1     0000-0003-0454-7145
# 2     0000-0002-9260-0753
# 3     0000-0002-0046-2219
# 4     0000-0003-0183-6910
# ...                   ...
# 1427  0000-0002-6148-6329
# 1428  0000-0002-6747-5524
# 1429  0000-0001-6816-8393
# 1430  0000-0002-5074-3254
# 1431  0000-0001-7553-6916
#
# [1432 rows x 4 columns]

# %%
# importing publisher JSON

with open("/content/drive/MyDrive/Colab Notebooks/graph_other_data.json", "r", encoding="utf-8") as f:
    json_doc = load(f)


# read just publishers

publisher = json_doc["publishers"]

# create the dataframe from json

df_publishers=pd.DataFrame(publisher.items(),columns=['crossref','name'])

df_publishers=pd.json_normalize(json.loads(df_publishers.to_json(orient="records")))
df_publishers.rename(columns={"name.id":"id","name.name":"name"}, inplace = True)

publisher_internal_id = {}
for idx, row in df_publishers.iterrows():
  local_id = "publisher-" + str(idx)

  subj = URIRef(base_url + local_id)

  publisher_internal_id[row["crossref"]] = subj


df_publishers
#publisher_internal_id
# Out:
#           crossref              id  \
# 0     crossref:735    crossref:735
# 1    crossref:2780   crossref:2780
# 2    crossref:2373   crossref:2373
# 3    crossref:2560   crossref:2560
# 4     crossref:311    crossref:311
# 5     crossref:320    crossref:320
# 6      crossref:98     crossref:98
# 7    crossref:1968   crossref:1968
# 8   crossref:22695  crossref:22695
# 9    crossref:2258   crossref:2258
# 10   crossref:6951   crossref:6951
# 11    crossref:374    crossref:374
# 12  crossref:11929  crossref:11929
# 13   crossref:1010   crossref:1010
# 14    crossref:237    crossref:237
# 15     crossref:78     crossref:78
# 16   crossref:2432   crossref:2432
# 17   crossref:4340   crossref:4340
# 18    crossref:301    crossref:301
# 19    crossref:340    crossref:340
# 20  crossref:17207  crossref:17207
# 21    crossref:281    crossref:281
# 22   crossref:2457   crossref:2457
# 23   crossref:7437   crossref:7437
# 24    crossref:263    crossref:263
# 25     crossref:56     crossref:56
# 26    crossref:297    crossref:297
# 27   crossref:6225   crossref:6225
# 28    crossref:179    crossref:179
# 29    crossref:265    crossref:265
# 30    crossref:316    crossref:316
# 31    crossref:286    crossref:286
# 32    crossref:140    crossref:140
# 33   crossref:8722   crossref:8722
# 34    crossref:530    crossref:530
# 35   crossref:3742   crossref:3742
# 36   crossref:4443   crossref:4443
#
#                                                  name
# 0                                 Thomas Telford Ltd.
# 1           The Korean Society of Medical Informatics
# 2                                      Editorial CSIC
# 3                                  F1000 Research Ltd
# 4                                               Wiley
# 5           Association for Computing Machinery (ACM)
# 6                                     Hindawi Limited
# 7                                             MDPI AG
# 8                      Polish Librarians' Association
# 9                                  Pensoft Publishers
# 10                                          Cogitatio
# 11                             Walter de Gruyter GmbH
# 12                Universidad Autonoma de Bucaramanga
# 13                             JMIR Publications Inc.
# 14                          The Company of Biologists
# 15                                        Elsevier BV
# 16                                         IGI Global
# 17                 Korean Home Management Association
# 18                                 Informa UK Limited
# 19                   Public Library of Science (PLoS)
# 20              Fundacion Universitaria San Pablo CEU
# 21                               MIT Press - Journals
# 22                      Trans Tech Publications, Ltd.
# 23                                          IOS Press
# 24  Institute of Electrical and Electronics Engine...
# 25                   Cambridge University Press (CUP)
# 26            Springer Science and Business Media LLC
# 27  National Academy of Sciences of Ukraine (Co. L...
# 28                                  SAGE Publications
# 29    Institution of Engineering and Technology (IET)
# 30                    American Chemical Society (ACS)
# 31                      Oxford University Press (OUP)
# 32                                            Emerald
# 33                                   The Open Journal
# 34                                FapUNIFESP (SciELO)
# 35            Sociedade Brasileira de Computacao - SB
# 36                                              PeerJ

# %% [markdown]
# ## struggling connections between publication with authors, publications with publishers,

# %%
from pandas import read_csv, Series

publications = read_csv("/content/drive/MyDrive/Colab Notebooks/graph_publications.csv", 
                  keep_default_na=False,
                  dtype={
                      "id": "string",
                      "title": "string",
                      "type": "string",
                      "publication_year": "int",
                      "issue": "string",
                      "volume": "string",
                      "chapter": "string",
                      "publication_venue": "string",
                      "venue_type": "string",
                      "publisher": "string",
                      "event": "string"
                  })

# Remove "doi:" from DOI
#doi = ["doi:", "DOI:"]

#for char in doi:
  #publications['id'] = publications['id'].str.replace(char,"")

#publications['id'] = publications['id'].str.split().str.join("")


publication_internal_id = {}
for idx, row in publications.iterrows():
    local_id = "publication-" + str(idx)
    
    # The shape of the new resources that are publications is
    # 'https://allorapy.github.io/res/publication-<integer>'
    subj = URIRef(base_url + local_id)
    
    # We put the new publication resources created here, to use them
    # when creating publications
    publication_internal_id[row["id"]] = subj
    
    if row["type"] == "journal-article":
        # RDF.type is the URIRef already provided by rdflib of the property 
        # 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'
        my_graph.add((subj, RDF.type, JournalArticle))
        
        # These two statements applies only to journal articles
        my_graph.add((subj, issue, Literal(row["issue"])))
        my_graph.add((subj, volume, Literal(row["volume"])))
    elif row["type"] == "book-chapter":
        # RDF.type is the URIRef already provided by rdflib of the property 
        # 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'
        my_graph.add((subj, RDF.type, BookChapter))
        
        # This statement applies only to book chapter
        my_graph.add((subj, chapterNumber, Literal(row["chapter"])))
    else:
        my_graph.add((subj, RDF.type, ProceedingsPaper))
        
        # This statement applies only to proceedings paper
        my_graph.add((subj, event, Literal(row["event"])))
    
    my_graph.add((subj, DCTERMS['title'], Literal(row["title"])))
    my_graph.add((subj, PRISM['doi'], Literal(row["id"])))
    
    
    # Defining subclasses
    my_graph.add((JournalArticle, RDFS.subClassOf, Publication))
    my_graph.add((BookChapter, RDFS.subClassOf, Publication))
    my_graph.add((ProceedingsPaper, RDFS.subClassOf, Publication))

    # Defining relations
    my_graph.add((subj, publicationVenue, Literal(row["publication_venue"])))

    
    # The URL of the related person is taken from the previous
    # dictionary defined when processing the authors
    my_graph.add((subj, author, person_internal_id[row["id"]]))

    # Tring to add to the publication the publisher
    # my_graph.add((subj, publisher, publisher_internal_id[row["publisher"]]))
    
    # The original value here has been casted to string since the Date type
    # in schema.org ('https://schema.org/Date') is actually a string-like value
    my_graph.add((subj, publicationYear, Literal(str(row["publication_year"]))))

# I create a set of venues in order to not have a venue title more than one time

venues_series = publications["publication_venue"] 

venues_set = set()

for idx, item in venues_series.iteritems():
    if item not in venues_set:
      venues_set.add(item)

# I create the DataFrame to iterate in order to create the "venues" subjects

df_venues = pd.DataFrame(venues_set)

df_venues.rename(columns={0:"title"}, inplace = True)


for idx, row in df_venues.iterrows():
    venue_local_id = "venue-" + str(idx)

    subj = URIRef(base_url + venue_local_id)

    # I assign the RDF.type and the title and add them to the graph
    my_graph.add((subj, RDF.type, Venue))
    my_graph.add((subj, DCTERMS['title'], Literal(row["title"])))

    # Defining relations
    #my_graph.add((subj, publisher, publisher_internal_id[row["publisher"]]))

publications
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-35-d331ae1f6783> in <module>()
#      74     # The URL of the related person is taken from the previous
#      75     # dictionary defined when processing the authors
# ---> 76     my_graph.add((subj, author, person_internal_id[row["id"]]))
#      77
#      78     # Tring to add to the publication the publisher
#
# /usr/local/lib/python3.7/dist-packages/rdflib/graph.py in add(self, triple)
#     426         assert isinstance(s, Node), "Subject %s must be an rdflib term" % (s,)
#     427         assert isinstance(p, Node), "Predicate %s must be an rdflib term" % (p,)
# --> 428         assert isinstance(o, Node), "Object %s must be an rdflib term" % (o,)
#     429         self.__store.add((s, p, o), self, quoted=False)
#     430         return self
#
# AssertionError: Object ['person-2'] must be an rdflib term

# %%
print("-- Number of triples added to the graph after processing the publications")
print(len(my_graph))

print(my_graph.serialize(format="turtle"))

# print namespaces used in the graph
# for prefix, ns in my_graph.namespaces():
#   print(ns)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# :person-957 a foaf:Person ;
#     foaf:familyName "Anzalone" ;
#     foaf:givenName "Alfred J" .
#
# :person-958 a foaf:Person ;
#     foaf:familyName "Callahan" ;
#     foaf:givenName "Tiffany J" .
#
# :person-959 a foaf:Person ;
#     foaf:familyName "Bramante" ;
#     foaf:givenName "Carolyn T" .
#
# :person-96 a foaf:Person ;
#     foaf:familyName "Vargas-Lombardo" ;
#     foaf:givenName "Miguel" .
#
# :person-960 a foaf:Person ;
#     foaf:familyName "Greene" ;
#     foaf:givenName "Casey S" .
#
# :person-961 a foaf:Person ;
#     foaf:familyName "Chu" ;
#     foaf:givenName "Haitao" .
#
# :person-962 a foaf:Person ;
#     foaf:familyName "Koraishy" ;
#     foaf:givenName "Farrukh M" .
#
# :person-963 a foaf:Person ;
#     foaf:familyName "Liang" ;
#     foaf:givenName "Chen" .
#
# :person-964 a foaf:Person ;
#     foaf:familyName "Liu" ;
#     foaf:givenName "Feifan" .
#
# :person-965 a foaf:Person ;
#     foaf:familyName "Mcnair" ;
#     foaf:givenName "Douglas S" .
#
# :person-966 a foaf:Person ;
#     foaf:familyName "Coleman" ;
#     foaf:givenName "Ben D" .
#
# :person-967 a foaf:Person ;
#     foaf:familyName "Perry" ;
#     foaf:givenName "Mallory A" .
#
# :person-968 a foaf:Person ;
#     foaf:familyName "Reese" ;
#     foaf:givenName "Justin T" .
#
# :person-969 a foaf:Person ;
#     foaf:familyName "Saltz" ;
#     foaf:givenName "Joel" .
#
# :person-97 a foaf:Person ;
#     foaf:familyName "Ren" ;
#     foaf:givenName "Yi" .
#
# :person-970 a foaf:Person ;
#     foaf:familyName "Solomonides" ;
#     foaf:givenName "Anthony E" .
#
# :person-971 a foaf:Person ;
#     foaf:familyName "Sule" ;
#     foaf:givenName "Anupam A" .
#
# :person-972 a foaf:Person ;
#     foaf:familyName "Madhira" ;
#     foaf:givenName "Vithal" .
#
# :person-973 a foaf:Person ;
#     foaf:familyName "Kavuluru" ;
#     foaf:givenName "Ramakanth" .
#
# :person-974 a foaf:Person ;
#     foaf:familyName "Chan" ;
#     foaf:givenName "Lauren E" .
#
# :person-975 a foaf:Person ;
#     foaf:familyName "Byrd" ;
#     foaf:givenName "James Brian" .
#
# :person-976 a foaf:Person ;
#     foaf:familyName "Mcmurry" ;
#     foaf:givenName "Julie A" .
#
# :person-977 a foaf:Person ;
#     foaf:familyName "Pfaff" ;
#     foaf:givenName "Emily" .
#
# :person-978 a foaf:Person ;
#     foaf:familyName "Matentzoglu" ;
#     foaf:givenName "Nicolas" .
#
# :person-979 a foaf:Person ;
#     foaf:familyName "Moffitt" ;
#     foaf:givenName "Richard A" .
#
# :person-98 a foaf:Person ;
#     foaf:familyName "Samuelsen" ;
#     foaf:givenName "Jeanette" .
#
# :person-980 a foaf:Person ;
#     foaf:familyName "Schuff" ;
#     foaf:givenName "Robert A" .
#
# :person-981 a foaf:Person ;
#     foaf:familyName "Bennett" ;
#     foaf:givenName "Tellen D" .
#
# :person-982 a foaf:Person ;
#     foaf:familyName "Wang" ;
#     foaf:givenName "Liwei" .
#
# :person-983 a foaf:Person ;
#     foaf:familyName "Robinson" ;
#     foaf:givenName "Peter N" .
#
# :person-984 a foaf:Person ;
#     foaf:familyName "Harris" ;
#     foaf:givenName "Midori A." .
#
# :person-985 a foaf:Person ;
#     foaf:familyName "Bähler" ;
#     foaf:givenName "Jürg" .
#
# :person-986 a foaf:Person ;
#     foaf:familyName "Oliver" ;
#     foaf:givenName "Stephen G." .
#
# :person-987 a foaf:Person ;
#     foaf:familyName "Mata" ;
#     foaf:givenName "Juan" .
#
# :person-988 a foaf:Person ;
#     foaf:familyName "Wood" ;
#     foaf:givenName "Valerie" .
#
# :person-989 a foaf:Person ;
#     foaf:familyName "Chiusano" ;
#     foaf:givenName "Maria Luisa" .
#
# :person-99 a foaf:Person ;
#     foaf:familyName "Romero" ;
#     foaf:givenName "Lucila" .
#
# :person-990 a foaf:Person ;
#     foaf:familyName "Bellen" ;
#     foaf:givenName "Hugo J." .
#
# :person-991 a foaf:Person ;
#     foaf:familyName "Konopka" ;
#     foaf:givenName "Tomasz" .
#
# :person-992 a foaf:Person ;
#     foaf:familyName "Ng" ;
#     foaf:givenName "Sandra" .
#
# :person-993 a foaf:Person ;
#     foaf:familyName "Baltoumas" ;
#     foaf:givenName "Fotis A." .
#
# :person-994 a foaf:Person ;
#     foaf:familyName "Karatzas" ;
#     foaf:givenName "Evangelos" .
#
# :person-995 a foaf:Person ;
#     foaf:familyName "Voutsadaki" ;
#     foaf:givenName "Kleanthi" .
#
# :person-996 a foaf:Person ;
#     foaf:familyName "Pavlopoulos" ;
#     foaf:givenName "Georgios A." .
#
# :person-997 a foaf:Person ;
#     foaf:familyName "Hoehndorf" ;
#     foaf:givenName "Robert" .
#
# :person-998 a foaf:Person ;
#     foaf:familyName "Jithesh" ;
#     foaf:givenName "Puthen Veettil" .
#
# :person-999 a foaf:Person ;
#     foaf:familyName "Holmgren" ;
#     foaf:givenName "Stephanie D." .
#
# :publication-0 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.websem.2021.100655" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Crossing The Chasm Between Ontology Engineering And Application Development: A Survey" ;
#     fabio:JournalVolume "70" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Journal Of Web Semantics" .
#
# :publication-1 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s10115-017-1100-y" ;
#     prism:issueIdentifier "3" ;
#     dcterms:title "Core Techniques Of Question Answering Systems Over Knowledge Bases: A Survey" ;
#     fabio:JournalVolume "55" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Knowledge And Information Systems" .
#
# :publication-10 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s10115-019-01401-x" ;
#     prism:issueIdentifier "5" ;
#     dcterms:title "Structured Query Construction Via Knowledge Graph Embedding" ;
#     fabio:JournalVolume "62" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Knowledge And Information Systems" .
#
# :publication-100 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.comcom.2021.04.024" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Ontology Knowledge Base Combined With Bayesian Networks For Integrated Corridor Risk Warning" ;
#     fabio:JournalVolume "174" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Computer Communications" .
#
# :publication-101 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-80847-1_9" ;
#     dcterms:title "Developing A Knowledge Base On Climate Change For Metropolitan Cities" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Ifip Advances In Information And Communication Technology - Artificial Intelligence For Knowledge Management" .
#
# :publication-102 a fabio:JournalArticle ;
#     prism:doi "doi:10.1080/0194262x.2021.1920555" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "Bibliometric Analysis On Bibliometric-Based Ontology Research" ;
#     fabio:JournalVolume "40" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Science & Technology Libraries" .
#
# :publication-103 a fabio:JournalArticle ;
#     prism:doi "doi:10.7466/jfbl.2020.38.4.1" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "An Ontology Of Intimate Partnerships For Social Big Data Research" ;
#     fabio:JournalVolume "38" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Journal Of Families And Better Life" .
#
# :publication-104 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/jrfm14060238" ;
#     prism:issueIdentifier "6" ;
#     dcterms:title "Intellectual Capital And Knowledge Management Research Towards Value Creation. From The Past To The Future" ;
#     fabio:JournalVolume "14" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Journal Of Risk And Financial Management" .
#
# :publication-105 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-7998-6792-0.ch005" ;
#     dcterms:title "Software Development Knowledge Management System Using Web Portal" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-106 a fabio:JournalArticle ;
#     prism:doi "doi:10.1111/exsy.12748" ;
#     prism:issueIdentifier "8" ;
#     dcterms:title "Using Semantic Annotations On Political Debate Videos For Building Open Government Based Lawmaking" ;
#     fabio:JournalVolume "38" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Expert Systems" .
#
# :publication-107 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/ani11010145" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Myfishcheck: A Model To Assess Fish Welfare In Aquaculture" ;
#     fabio:JournalVolume "11" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Animals" .
#
# :publication-108 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/axioms10020093" ;
#     prism:issueIdentifier "2" ;
#     dcterms:title "Transdisciplinary Scientific Strategies For Soft Computing Development: Towards An Era Of Data And Business Analytics" ;
#     fabio:JournalVolume "10" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Axioms" .
#
# :publication-109 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-7998-6874-3.ch006" ;
#     dcterms:title "Semantically Enhanced Web Service For Global Supply Chain Disruption Management" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-11 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-30793-6_22" ;
#     dcterms:title "Difficulty-Controllable Multi-Hop Question Generation From Knowledge Graphs" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Lecture Notes In Computer Science - The Semantic Web – Iswc 2019" .
#
# :publication-110 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/encyclopedia1010015" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Ontologies In Knowledge Organization" ;
#     fabio:JournalVolume "1" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Encyclopedia" .
#
# :publication-111 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.compind.2020.103374" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "An Ontology-Based Framework To Formalize And Represent 4D Printing Knowledge In Design" ;
#     fabio:JournalVolume "126" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Computers In Industry" .
#
# :publication-112 a fabio:JournalArticle ;
#     prism:doi "doi:10.1017/s0890060421000147" ;
#     prism:issueIdentifier "3" ;
#     dcterms:title "Intelligent Product Redesign Strategy With Ontology-Based Fine-Grained Sentiment Analysis" ;
#     fabio:JournalVolume "35" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Artificial Intelligence For Engineering Design, Analysis And Manufacturing" .
#
# :publication-113 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/app11125633" ;
#     prism:issueIdentifier "12" ;
#     dcterms:title "Semantic Microservice Framework For Digital Twins" ;
#     fabio:JournalVolume "11" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Applied Sciences" .
#
# :publication-114 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/met11071025" ;
#     prism:issueIdentifier "7" ;
#     dcterms:title "A Decision Support System For Changes In Operation Modes Of The Copper Heap Leaching Process" ;
#     fabio:JournalVolume "11" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Metals" .
#
# :publication-115 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-79150-6_10" ;
#     dcterms:title "An Ontology-Based Concept For Meta Automl" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Ifip Advances In Information And Communication Technology - Artificial Intelligence Applications And Innovations" .
#
# :publication-116 a fabio:JournalArticle ;
#     prism:doi "doi:10.1111/nbu.12482" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Personalised Nutrition For Healthy Living: The Protein Project" ;
#     fabio:JournalVolume "46" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Nutrition Bulletin" .
#
# :publication-117 a fabio:JournalArticle ;
#     prism:doi "doi:10.1177/01655515211022185" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Using Iso And Semantic Web Standard For Building A Multilingual Terminology E-Dictionary: A Use Case Of Chinese Ceramic Vases" ;
#     fabio:JournalVolume "" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Journal Of Information Science" .
#
# :publication-118 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s11069-021-04742-5" ;
#     prism:issueIdentifier "2" ;
#     dcterms:title "Integration Of A Geo-Ontology-Based Knowledge Model And Spatial Analysis Into Emergency Response For Geologic Hazards" ;
#     fabio:JournalVolume "108" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Natural Hazards" .
#
# :publication-119 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/asi4010021" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "An Ontological Approach For Early Detection Of Suspected Covid-19 Among Copd Patients" ;
#     fabio:JournalVolume "4" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Applied System Innovation" .
#
# :publication-12 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-33220-4_25" ;
#     dcterms:title "Quant - Question Answering Benchmark Curator" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Lecture Notes In Computer Science - Semantic Systems. The Power Of Ai And Knowledge Graphs" .
#
# :publication-120 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/electronics10080905" ;
#     prism:issueIdentifier "8" ;
#     dcterms:title "Knowledge-Based System For Crop Pests And Diseases Recognition" ;
#     fabio:JournalVolume "10" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Electronics" .
#
# :publication-121 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/app11157056" ;
#     prism:issueIdentifier "15" ;
#     dcterms:title "Towards Collaborative And Dynamic Spectrum Sharing Via Interpretation Of Spectrum Access Policies" ;
#     fabio:JournalVolume "11" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Applied Sciences" .
#
# :publication-122 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-79022-6_10" ;
#     dcterms:title "Ontology-Driven Audit Using The Rea-Ontology" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Lecture Notes In Business Information Processing - Advanced Information Systems Engineering Workshops" .
#
# :publication-123 a fabio:JournalArticle ;
#     prism:doi "doi:10.1002/widm.1413" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "Incorporating Domain Ontology Information Into Clustering In Heterogeneous Networks" ;
#     fabio:JournalVolume "11" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Wires Data Mining And Knowledge Discovery" .
#
# :publication-124 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-72657-7_24" ;
#     dcterms:title "Automatic Classifier Of Scientific Contents" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Advances In Intelligent Systems And Computing - Trends And Applications In Information Systems And Technologies" .
#
# :publication-125 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-5225-7501-6.ch036" ;
#     dcterms:title "Supply Chain Coordination Based On Web Service" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-126 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-5225-8223-6.ch008" ;
#     dcterms:title "Semantic Web Service For Global Apparel Business" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-127 a fabio:JournalArticle ;
#     prism:doi "doi:10.1080/0951192x.2019.1571236" ;
#     prism:issueIdentifier "4-5" ;
#     dcterms:title "Prima: A Prescriptive Maintenance Model For Cyber-Physical Production Systems" ;
#     fabio:JournalVolume "32" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "International Journal Of Computer Integrated Manufacturing" .
#
# :publication-128 a fabio:JournalArticle ;
#     prism:doi "doi:10.1080/0951192x.2019.1599443" ;
#     prism:issueIdentifier "7" ;
#     dcterms:title "Enhancing Supply Chain Resilience Using Ontology-Based Decision Support System" ;
#     fabio:JournalVolume "32" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "International Journal Of Computer Integrated Manufacturing" .
#
# :publication-129 a fabio:JournalArticle ;
#     prism:doi "doi:10.1080/09544828.2019.1643830" ;
#     prism:issueIdentifier "10-12" ;
#     dcterms:title "Analogical Stimuli Retrieval Approach Based On R-Sbf Ontology Model" ;
#     fabio:JournalVolume "30" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Journal Of Engineering Design" .
#
# :publication-13 a fabio:JournalArticle ;
#     prism:doi "doi:10.1080/17538947.2020.1738568" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Geo-Analytical Question-Answering With Gis" ;
#     fabio:JournalVolume "14" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "International Journal Of Digital Earth" .
#
# :publication-130 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-319-61911-8_13" ;
#     dcterms:title "Sentiment Polarity Detection In Social Networks: An Approach For Asthma Disease Management" ;
#     fabio:hasPublicationYear "2017" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Advanced Computational Methods For Knowledge Engineering - Advances In Intelligent Systems And Computing" .
#
# :publication-131 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-319-67283-0_4" ;
#     dcterms:title "An Ontology-Based Decision Support System For The Management Of Home Gardens" ;
#     fabio:hasPublicationYear "2017" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Communications In Computer And Information Science - Technologies And Innovation" .
#
# :publication-132 a fabio:JournalArticle ;
#     prism:doi "doi:10.1108/jd-10-2017-0139" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "User Conceptualizations Of Derivative Relationships In The Bibliographic Universe" ;
#     fabio:JournalVolume "74" ;
#     fabio:hasPublicationYear "2018" ;
#     schema:isPartOf "Journal Of Documentation" .
#
# :publication-133 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-24289-3_20" ;
#     dcterms:title "A Knowledge-Based Computational Environment For Real-World Data Processing" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Computational Science And Its Applications – Iccsa 2019 - Lecture Notes In Computer Science" .
#
# :publication-134 a fabio:JournalArticle ;
#     prism:doi "doi:10.1017/s0269888916000011" ;
#     prism:issueIdentifier "2" ;
#     dcterms:title "Scientific Knowledge Engineering: A Conceptual Delineation And Overview Of The State Of The Art" ;
#     fabio:JournalVolume "31" ;
#     fabio:hasPublicationYear "2016" ;
#     schema:isPartOf "The Knowledge Engineering Review" .
#
# :publication-135 a fabio:JournalArticle ;
#     prism:doi "doi:10.1017/s0269888918000139" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Knowledge Machines" ;
#     fabio:JournalVolume "33" ;
#     fabio:hasPublicationYear "2018" ;
#     schema:isPartOf "The Knowledge Engineering Review" .
#
# :publication-136 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-5225-0956-1.ch009" ;
#     dcterms:title "Supply Chain Coordination Based On Web Service" ;
#     fabio:hasPublicationYear "2017" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-137 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-30760-8_23" ;
#     dcterms:title "Information Governance Maturity Assessment Using Enterprise Architecture Model Analysis And Description Logics" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Digital Libraries For Open Knowledge - Lecture Notes In Computer Science" .
#
# :publication-138 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s11095-017-2308-y" ;
#     prism:issueIdentifier "12" ;
#     dcterms:title "Model-Based Methods In The Biopharmaceutical Process Lifecycle" ;
#     fabio:JournalVolume "34" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Pharmaceutical Research" .
#
# :publication-139 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-319-74433-9_2" ;
#     dcterms:title "Semantic Discovery In The Web Of Things" ;
#     fabio:hasPublicationYear "2018" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Current Trends In Web Engineering - Lecture Notes In Computer Science" .
#
# :publication-14 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s10462-020-09826-5" ;
#     prism:issueIdentifier "7" ;
#     dcterms:title "A Short Survey On End-To-End Simple Question Answering Systems" ;
#     fabio:JournalVolume "53" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Artificial Intelligence Review" .
#
# :publication-140 a fabio:JournalArticle ;
#     prism:doi "doi:10.1017/s1351324918000347" ;
#     prism:issueIdentifier "6" ;
#     dcterms:title "Models To Represent Linguistic Linked Data" ;
#     fabio:JournalVolume "24" ;
#     fabio:hasPublicationYear "2018" ;
#     schema:isPartOf "Natural Language Engineering" .
#
# :publication-141 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-10728-4_4" ;
#     dcterms:title "A Rule-Based Expert System For Cow Disease Diagnosis" ;
#     fabio:hasPublicationYear "2018" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Ict For Agriculture And Environment - Advances In Intelligent Systems And Computing" .
#
# :publication-142 a fabio:JournalArticle ;
#     prism:doi "doi:10.1002/ett.3625" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Cognitive Internet Of Vehicles And Disaster Management: A Proposed Architecture And Future Direction" ;
#     fabio:JournalVolume "" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Transactions On Emerging Telecommunications Technologies" .
#
# :publication-143 a fabio:JournalArticle ;
#     prism:doi "doi:10.1186/s40561-017-0046-6" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Evaluating The Quality Of The Ontology-Based Auto-Generated Questions" ;
#     fabio:JournalVolume "4" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Smart Learning Environments" .
#
# :publication-144 a fabio:JournalArticle ;
#     prism:doi "doi:10.1017/aer.2019.74" ;
#     prism:issueIdentifier "1268" ;
#     dcterms:title "Semantics-Based Summarisation Of Atm Information" ;
#     fabio:JournalVolume "123" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "The Aeronautical Journal" .
#
# :publication-145 a fabio:JournalArticle ;
#     prism:doi "doi:10.1080/00207543.2017.1415468" ;
#     prism:issueIdentifier "8" ;
#     dcterms:title "Human Resource Optimisation Through Semantically Enriched Data" ;
#     fabio:JournalVolume "56" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "International Journal Of Production Research" .
#
# :publication-146 a fabio:JournalArticle ;
#     prism:doi "doi:10.1680/jmapl.17.00052" ;
#     prism:issueIdentifier "3" ;
#     dcterms:title "An Ontology-Based Data Integration Framework For Construction Information Management" ;
#     fabio:JournalVolume "171" ;
#     fabio:hasPublicationYear "2018" ;
#     schema:isPartOf "Proceedings Of The Institution Of Civil Engineers - Management, Procurement And Law" .
#
# :publication-147 a fabio:JournalArticle ;
#     prism:doi "doi:10.1186/s13326-017-0154-9" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Analysis And Visualization Of Disease Courses In A Semantically-Enabled Cancer Registry" ;
#     fabio:JournalVolume "8" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Journal Of Biomedical Semantics" .
#
# :publication-148 a fabio:JournalArticle ;
#     prism:doi "doi:10.1186/s13326-017-0158-5" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "A Histological Ontology Of The Human Cardiovascular System" ;
#     fabio:JournalVolume "8" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Journal Of Biomedical Semantics" .
#
# :publication-149 a fabio:JournalArticle ;
#     prism:doi "doi:10.1109/access.2016.2621756" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "A New Fuzzy Ontology Development Methodology (Fodm) Proposal" ;
#     fabio:JournalVolume "4" ;
#     fabio:hasPublicationYear "2016" ;
#     schema:isPartOf "Ieee Access" .
#
# :publication-15 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-49461-2_25" ;
#     dcterms:title "Qanswer Kg: Designing A Portable Question Answering System Over Rdf Data" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "The Semantic Web - Lecture Notes In Computer Science" .
#
# :publication-150 a fabio:JournalArticle ;
#     prism:doi "doi:10.1109/access.2017.2734681" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Network Security Situation Awareness Based On Semantic Ontology And User-Defined Rules For Internet Of Things" ;
#     fabio:JournalVolume "5" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Ieee Access" .
#
# :publication-151 a fabio:JournalArticle ;
#     prism:doi "doi:10.1109/tip.2016.2552401" ;
#     prism:issueIdentifier "7" ;
#     dcterms:title "Ontology-Based Semantic Image Segmentation Using Mixture Models And Multiple Crfs" ;
#     fabio:JournalVolume "25" ;
#     fabio:hasPublicationYear "2016" ;
#     schema:isPartOf "Ieee Transactions On Image Processing" .
#
# :publication-152 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/app10020591" ;
#     prism:issueIdentifier "2" ;
#     dcterms:title "An Analytical Game For Knowledge Acquisition For Maritime Behavioral Analysis Systems" ;
#     fabio:JournalVolume "10" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Applied Sciences" .
#
# :publication-153 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/app10031040" ;
#     prism:issueIdentifier "3" ;
#     dcterms:title "Agrient: A Knowledge-Based Web Platform For Managing Insect Pests Of Field Crops" ;
#     fabio:JournalVolume "10" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Applied Sciences" .
#
# :publication-154 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s12652-019-01561-2" ;
#     prism:issueIdentifier "11" ;
#     dcterms:title "Using Lot Methodology To Develop A Noise Pollution Ontology: A Spanish Use Case" ;
#     fabio:JournalVolume "11" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Journal Of Ambient Intelligence And Humanized Computing" .
#
# :publication-155 a fabio:JournalArticle ;
#     prism:doi "doi:10.36702/zin.495" ;
#     prism:issueIdentifier "1(113)" ;
#     dcterms:title "Deconstructing The Scholarly Paper. Ontologies For Semantic Publishing" ;
#     fabio:JournalVolume "57" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Zagadnienia Informacji Naukowej - Studia Informacyjne" .
#
# :publication-156 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-37933-9_8" ;
#     dcterms:title "Maturity Assessment Of Togaf Adm Using Enterprise Architecture Model Analysis And Description Logics" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Advances In Enterprise Engineering Xiii - Lecture Notes In Business Information Processing" .
#
# :publication-157 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-35249-3_66" ;
#     dcterms:title "Knowledge Base Intelligent System Of Optimal Locations For Safe Water Wells" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Advances In Intelligent Systems And Computing - 10Th International Conference On Theory And Application Of Soft Computing, Computing With Words And Perceptions - Icsccw-2019" .
#
# :publication-158 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-34146-6_23" ;
#     dcterms:title "The Ontooo-Method: An Ontology-Driven Conceptual Modeling Approach For Evolving The Oo-Method" ;
#     fabio:hasPublicationYear "2019" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Lecture Notes In Computer Science - Advances In Conceptual Modeling" .
#
# :publication-159 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-42517-3_1" ;
#     dcterms:title "Comparative Study Of Rdf And Owl Ontology Languages As Support For The Semantic Web" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Communications In Computer And Information Science - Applied Technologies" .
#
# :publication-16 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s10462-020-09866-x" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Survey On Evaluation Methods For Dialogue Systems" ;
#     fabio:JournalVolume "54" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Artificial Intelligence Review" .
#
# :publication-160 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-7998-1863-2.ch002" ;
#     dcterms:title "Fuzzy Ontology For Requirements Determination And Documentation During Software Development" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-161 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-7998-1934-9.ch013" ;
#     dcterms:title "Model Based On Ontological Engineering As Support For Stakeholder Management" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-162 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-7998-2104-5.ch009" ;
#     dcterms:title "Contemporary Archival Description As Required Digital Competence Of Today'S Archivists" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-163 a fabio:JournalArticle ;
#     prism:doi "doi:10.1017/s0269888919000237" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "A Review And Comparison Of Ontology-Based Approaches To Robot Autonomy" ;
#     fabio:JournalVolume "34" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "The Knowledge Engineering Review" .
#
# :publication-164 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/app10072277" ;
#     prism:issueIdentifier "7" ;
#     dcterms:title "The Systematic Design Of Industrial Products Through Design Archetypes: An Application On Mechanical Transmissions" ;
#     fabio:JournalVolume "10" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Applied Sciences" .
#
# :publication-165 a fabio:JournalArticle ;
#     prism:doi "doi:10.1590/1678-9865202032e180077" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Construcción De Una Red De Ontologías Sobre Eventos Meteorológicos A Partir De Periódicos Históricos" ;
#     fabio:JournalVolume "32" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Transinformação" .
#
# :publication-166 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/su11236549" ;
#     prism:issueIdentifier "23" ;
#     dcterms:title "Social Parking: Applying The Citizens As Sensors Paradigm To Parking Guidance And Information" ;
#     fabio:JournalVolume "11" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Sustainability" .
#
# :publication-167 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-39459-2_2" ;
#     dcterms:title "Optimized Term Extraction Method Based On Computing Merged Partial C-Values" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Information And Communication Technologies In Education, Research, And Industrial Applications - Communications In Computer And Information Science" .
#
# :publication-168 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s11629-019-5576-7" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "Augmented Planning Support System Framework For Mountainous Urban Master Planning" ;
#     fabio:JournalVolume "17" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Journal Of Mountain Science" .
#
# :publication-169 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-45442-5_15" ;
#     dcterms:title "Machine-Actionable Data Management Plans: A Knowledge Retrieval Approach To Automate The Assessment Of Funders’ Requirements" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Lecture Notes In Computer Science - Advances In Information Retrieval" .
#
# :publication-17 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s10796-020-10035-2" ;
#     prism:issueIdentifier "5" ;
#     dcterms:title "An Overview Of Utilizing Knowledge Bases In Neural Networks For Question Answering" ;
#     fabio:JournalVolume "22" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Information Systems Frontiers" .
#
# :publication-170 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s10115-020-01498-5" ;
#     prism:issueIdentifier "11" ;
#     dcterms:title "Snowl Model: Social Networks Unification-Based Semantic Data Integration" ;
#     fabio:JournalVolume "62" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Knowledge And Information Systems" .
#
# :publication-171 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s12652-020-02150-4" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Ontological Concepts For Information Sharing In Cloud Robotics" ;
#     fabio:JournalVolume "" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Journal Of Ambient Intelligence And Humanized Computing" .
#
# :publication-172 a fabio:JournalArticle ;
#     prism:doi "doi:10.1017/s0266462320000471" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "Exploring The Identification, Validation, And Categorization Of The Cost And Benefits Of Criminal Justice In Mental Health: The Pecunia Project" ;
#     fabio:JournalVolume "36" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "International Journal Of Technology Assessment In Health Care" .
#
# :publication-173 a fabio:JournalArticle ;
#     prism:doi "doi:10.1177/1420326x20952817" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Simulated Physical Ageing: A Prioritized Persona-Based Model For Accessible Interiors In Senior Housing Environments" ;
#     fabio:JournalVolume "" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Indoor And Built Environment" .
#
# :publication-174 a fabio:BookChapter ;
#     prism:doi "doi:10.4018/978-1-7998-4240-8.ch004" ;
#     dcterms:title "Sentiment Analysis As A Restricted Nlp Problem" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "0" ;
#     schema:isPartOf "" .
#
# :publication-175 a fabio:JournalArticle ;
#     prism:doi "doi:10.1108/ajim-11-2019-0320" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "Participatory Design For Ontologies: A Case Study Of An Open Science Ontology For Qualitative Coding Schemas" ;
#     fabio:JournalVolume "72" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Aslib Journal Of Information Management" .
#
# :publication-176 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/ijgi9100588" ;
#     prism:issueIdentifier "10" ;
#     dcterms:title "A Built Heritage Information System Based On Point Cloud Data: His-Pc" ;
#     fabio:JournalVolume "9" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Isprs International Journal Of Geo-Information" .
#
# :publication-177 a fabio:JournalArticle ;
#     prism:doi "doi:10.1002/eng2.12217" ;
#     prism:issueIdentifier "8" ;
#     dcterms:title "What Is Knowledge In Industry 4.0?" ;
#     fabio:JournalVolume "2" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Engineering Reports" .
#
# :publication-178 a fabio:JournalArticle ;
#     prism:doi "doi:10.1111/exsy.12629" ;
#     prism:issueIdentifier "2" ;
#     dcterms:title "A Semantic‐Enabled And Context‐Aware Monitoring System For The Internet Of Medical Things" ;
#     fabio:JournalVolume "38" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Expert Systems" .
#
# :publication-179 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-62015-8_2" ;
#     dcterms:title "Croppesto: An Ontology Model For Identifying And Managing Plant Pests And Diseases" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Communications In Computer And Information Science - Technologies And Innovation" .
#
# :publication-18 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-60276-5_25" ;
#     dcterms:title "Legal Tech: Documents’ Validation Method Based On The Associative-Ontological Approach" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Speech And Computer - Lecture Notes In Computer Science" .
#
# :publication-180 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/designs4040047" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "Sympérasmology: A Proposal For The Theory Of Synthetic System Knowledge" ;
#     fabio:JournalVolume "4" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Designs" .
#
# :publication-181 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/en13153990" ;
#     prism:issueIdentifier "15" ;
#     dcterms:title "Constrained Generation Bids In Local Electricity Markets: A Semantic Approach" ;
#     fabio:JournalVolume "13" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Energies" .
#
# :publication-182 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-63799-6_17" ;
#     dcterms:title "Semantic Technologies Towards Accountable Artificial Intelligence: A Poultry Chain Management Use Case" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Lecture Notes In Computer Science - Artificial Intelligence Xxxvii" .
#
# :publication-183 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-64058-3_67" ;
#     dcterms:title "Artificial Intelligence For Lassa Fever Diagnosis System" ;
#     fabio:hasPublicationYear "2021" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Advances In Intelligent Systems And Computing - 14Th International Conference On Theory And Application Of Fuzzy Systems And Soft Computing – Icafs-2020" .
#
# :publication-184 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-65847-2_11" ;
#     dcterms:title "Mapping The Web Ontology Language To The Openapi Specification" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Lecture Notes In Computer Science - Advances In Conceptual Modeling" .
#
# :publication-185 a fabio:JournalArticle ;
#     prism:doi "doi:10.15407/csc.2020.04.044" ;
#     prism:issueIdentifier "4 (288)" ;
#     dcterms:title "Ontology Application To Construct Inductive Modeling Tools With Intelligent Interface" ;
#     fabio:JournalVolume "" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Control Systems And Computers" .
#
# :publication-186 a fabio:JournalArticle ;
#     prism:doi "doi:10.1108/jmtm-04-2020-0137" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Application Of Design Thinking To Product-Configuration Projects" ;
#     fabio:JournalVolume "32" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Journal Of Manufacturing Technology Management" .
#
# :publication-187 a fabio:JournalArticle ;
#     prism:doi "doi:10.1186/s12911-020-01291-y" ;
#     prism:issueIdentifier "S10" ;
#     dcterms:title "Analysis Of Readability And Structural Accuracy In Snomed Ct" ;
#     fabio:JournalVolume "20" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Bmc Medical Informatics And Decision Making" .
#
# :publication-188 a fabio:JournalArticle ;
#     prism:doi "doi:10.2196/20443" ;
#     prism:issueIdentifier "7" ;
#     dcterms:title "Ontological Organization And Bioinformatic Analysis Of Adverse Drug Reactions From Package Inserts: Development And Usability Study" ;
#     fabio:JournalVolume "22" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Journal Of Medical Internet Research" .
#
# :publication-189 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.jvolgeores.2014.07.012" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Knowledge Engineering In Volcanology: Practical Claims And General Approach" ;
#     fabio:JournalVolume "286" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Journal Of Volcanology And Geothermal Research" .
#
# :publication-19 a fabio:BookChapter ;
#     prism:doi "doi:10.1007/978-3-030-54956-5_2" ;
#     dcterms:title "Question Answering On Scholarly Knowledge Graphs" ;
#     fabio:hasPublicationYear "2020" ;
#     fabio:hasSequenceIdentifier "1" ;
#     schema:isPartOf "Digital Libraries For Open Knowledge - Lecture Notes In Computer Science" .
#
# :publication-190 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.cirpj.2018.06.002" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "A Problem-Solving Ontology For Human-Centered Cyber Physical Production Systems" ;
#     fabio:JournalVolume "22" ;
#     fabio:hasPublicationYear "2018" ;
#     schema:isPartOf "Cirp Journal Of Manufacturing Science And Technology" .
#
# :publication-191 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.ijinfomgt.2016.05.022" ;
#     prism:issueIdentifier "6" ;
#     dcterms:title "Towards Knowledge Modeling And Manipulation Technologies: A Survey" ;
#     fabio:JournalVolume "36" ;
#     fabio:hasPublicationYear "2016" ;
#     schema:isPartOf "International Journal Of Information Management" .
#
# :publication-192 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.cmpb.2014.01.020" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Bioss: A System For Biomedical Ontology Selection" ;
#     fabio:JournalVolume "114" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Computer Methods And Programs In Biomedicine" .
#
# :publication-193 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.comcom.2019.02.002" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "The Mom Of Context-Aware Systems: A Survey" ;
#     fabio:JournalVolume "137" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Computer Communications" .
#
# :publication-194 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.eswa.2014.03.022" ;
#     prism:issueIdentifier "13" ;
#     dcterms:title "Feature-Based Opinion Mining Through Ontologies" ;
#     fabio:JournalVolume "41" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Expert Systems With Applications" .
#
# :publication-195 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.eswa.2020.113843" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Development Of A Consumer Financial Goals Ontology For Use With Fintech Applications For Improving Financial Capability" ;
#     fabio:JournalVolume "165" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Expert Systems With Applications" .
#
# :publication-196 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.ecoinf.2017.06.003" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Ontology-Based Support For Taxonomic Functions" ;
#     fabio:JournalVolume "41" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Ecological Informatics" .
#
# :publication-197 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.datak.2014.07.006" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Reducing The Gap Between Experts' Knowledge And Data: The Tom4D Methodology" ;
#     fabio:JournalVolume "94" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Data & Knowledge Engineering" .
#
# :publication-198 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.cmpb.2013.12.023" ;
#     prism:issueIdentifier "3" ;
#     dcterms:title "Ontology Driven Decision Support For The Diagnosis Of Mild Cognitive Impairment" ;
#     fabio:JournalVolume "113" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Computer Methods And Programs In Biomedicine" .
#
# :publication-199 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.cosrev.2020.100339" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Ontology Learning: Grand Tour And Challenges" ;
#     fabio:JournalVolume "39" ;
#     fabio:hasPublicationYear "2021" ;
#     schema:isPartOf "Computer Science Review" .
#
# :publication-2 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.websem.2014.03.003" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Api-Centric Linked Data Integration: The Open Phacts Discovery Platform Case Study" ;
#     fabio:JournalVolume "29" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Journal Of Web Semantics" .
#
# :publication-20 a fabio:JournalArticle ;
#     prism:doi "doi:10.1007/s11280-020-00836-5" ;
#     prism:issueIdentifier "1" ;
#     dcterms:title "Temporal Knowledge Extraction From Large-Scale Text Corpus" ;
#     fabio:JournalVolume "24" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "World Wide Web" .
#
# :publication-200 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.rser.2015.04.021" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Ontology Of Ground Source Heat Pump" ;
#     fabio:JournalVolume "49" ;
#     fabio:hasPublicationYear "2015" ;
#     schema:isPartOf "Renewable And Sustainable Energy Reviews" .
#
# :publication-201 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.scico.2018.01.003" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "An Ontology-Based Approach With Which To Assign Human Resources To Software Projects" ;
#     fabio:JournalVolume "156" ;
#     fabio:hasPublicationYear "2018" ;
#     schema:isPartOf "Science Of Computer Programming" .
#
# :publication-202 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.rcim.2019.05.010" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Core Domain Ontology For Joining Processes To Consolidate Welding Standards" ;
#     fabio:JournalVolume "59" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Robotics And Computer-Integrated Manufacturing" .
#
# :publication-203 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.aei.2018.10.009" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Modelling Residual Value Risk Through Ontology To Address Vulnerability Of Ppp Project System" ;
#     fabio:JournalVolume "38" ;
#     fabio:hasPublicationYear "2018" ;
#     schema:isPartOf "Advanced Engineering Informatics" .
#
# :publication-204 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.future.2018.01.062" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Experience Based Knowledge Representation For Internet Of Things And Cyber Physical Systems With Case Studies" ;
#     fabio:JournalVolume "92" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Future Generation Computer Systems" .
#
# :publication-205 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.pmcj.2016.03.001" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Towards A Social And Context-Aware Mobile Recommendation System For Tourism" ;
#     fabio:JournalVolume "38" ;
#     fabio:hasPublicationYear "2017" ;
#     schema:isPartOf "Pervasive And Mobile Computing" .
#
# :publication-206 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.jmsy.2014.05.003" ;
#     prism:issueIdentifier "4" ;
#     dcterms:title "Development Of A Hybrid Manufacturing Cloud" ;
#     fabio:JournalVolume "33" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Journal Of Manufacturing Systems" .
#
# :publication-207 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.compind.2019.05.003" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Ontology-Based Systems Engineering: A State-Of-The-Art Review" ;
#     fabio:JournalVolume "111" ;
#     fabio:hasPublicationYear "2019" ;
#     schema:isPartOf "Computers In Industry" .
#
# :publication-208 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.knosys.2013.10.006" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Ontology-Based Annotation And Retrieval Of Services In The Cloud" ;
#     fabio:JournalVolume "56" ;
#     fabio:hasPublicationYear "2014" ;
#     schema:isPartOf "Knowledge-Based Systems" .
#
# :publication-209 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.compchemeng.2016.05.018" ;
#     prism:issueIdentifier "" ;
#     dcterms:title "Semantically Enabled Process Synthesis And Optimisation" ;
#     fabio:JournalVolume "93" ;
#     fabio:hasPublicationYear "2016" ;
#     schema:isPartOf "Computers & Chemical Engineering" .
#
# :publication-21 a fabio:JournalArticle ;
#     prism:doi "doi:10.3390/a13090217" ;
#     prism:issueIdentifier "9" ;
#     dcterms:title "R2D2: A Dbpedia Chatbot Using Triple-Pattern Like Queries" ;
#     fabio:JournalVolume "13" ;
#     fabio:hasPublicationYear "2020" ;
#     schema:isPartOf "Algorithms" .
#
# :publication-210 a fabio:JournalArticle ;
#     prism:doi "doi:10.1016/j.compmedimag.2014.09.004" ;
#     prism:issueIdentifier "" ;
# ...
#
# :venue-248 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Big Earth Data" .
#
# :venue-249 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Public Administration In The Digital Age" .
#
# :venue-25 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Expert Systems" .
#
# :venue-250 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Computational Physics" .
#
# :venue-251 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Healthcare Informatics Research" .
#
# :venue-252 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Artificial Intelligence Review" .
#
# :venue-253 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Multimedia Systems" .
#
# :venue-254 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "The Journal Of Agricultural Science" .
#
# :venue-255 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Sensors" .
#
# :venue-256 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal On Digital Libraries" .
#
# :venue-257 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Database" .
#
# :venue-258 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Human Mutation" .
#
# :venue-259 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Medical Systems" .
#
# :venue-26 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Manufacturing Technology Management" .
#
# :venue-260 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Revista Española De Documentación Científica" .
#
# :venue-261 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Natural Hazards" .
#
# :venue-262 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Bioinformatics" .
#
# :venue-263 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Computerized Medical Imaging And Graphics" .
#
# :venue-264 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Aslib Journal Of Information Management" .
#
# :venue-265 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Open Source Software" .
#
# :venue-266 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Volcanology And Geothermal Research" .
#
# :venue-267 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes Of The Institute For Computer Sciences, Social Informatics And Telecommunications Engineering - Cloud Computing" .
#
# :venue-268 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Future Generation Computer Systems" .
#
# :venue-269 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Complexity" .
#
# :venue-27 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Publications" .
#
# :venue-270 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Wireless Networks" .
#
# :venue-271 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Nature Reviews Nephrology" .
#
# :venue-272 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Nature Communications" .
#
# :venue-273 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Theory And Practice Of Logic Programming" .
#
# :venue-274 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Language Resources And Evaluation" .
#
# :venue-275 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Sustainability" .
#
# :venue-276 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Personal And Ubiquitous Computing" .
#
# :venue-277 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Ifip Advances In Information And Communication Technology - Artificial Intelligence For Knowledge Management" .
#
# :venue-278 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Information Science" .
#
# :venue-279 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Electronics" .
#
# :venue-28 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Data And Information Quality" .
#
# :venue-280 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Nature Genetics" .
#
# :venue-281 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Metadata And Semantic Research - Communications In Computer And Information Science" .
#
# :venue-282 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Computer And System Sciences" .
#
# :venue-283 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Artificial Intelligence For Engineering Design, Analysis And Manufacturing" .
#
# :venue-284 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Smart Learning Environments" .
#
# :venue-285 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Cyberspace Safety And Security - Lecture Notes In Computer Science" .
#
# :venue-286 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Policy & Internet" .
#
# :venue-287 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Plos One" .
#
# :venue-288 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Documentation" .
#
# :venue-289 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Energy Research" .
#
# :venue-29 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Iet Software" .
#
# :venue-290 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "The Semantic Web - Lecture Notes In Computer Science" .
#
# :venue-291 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Expert Systems With Applications" .
#
# :venue-292 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Speech And Computer - Lecture Notes In Computer Science" .
#
# :venue-293 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "New Generation Computing" .
#
# :venue-294 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Advanced Engineering Informatics" .
#
# :venue-295 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Computer Integrated Manufacturing" .
#
# :venue-296 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Data Intelligence" .
#
# :venue-297 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Educational Technology Research And Development" .
#
# :venue-298 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Nutrition Bulletin" .
#
# :venue-299 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Current Trends In Web Engineering - Lecture Notes In Computer Science" .
#
# :venue-3 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Jamia Open" .
#
# :venue-30 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Human-Centric Computing And Information Sciences" .
#
# :venue-31 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Computers And Electronics In Agriculture" .
#
# :venue-32 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Formal Concept Analysis - Lecture Notes In Computer Science" .
#
# :venue-33 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Internet Services And Applications" .
#
# :venue-34 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Topics In Current Chemistry" .
#
# :venue-35 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Cogent Engineering" .
#
# :venue-36 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes In Computer Science - Semantic Systems. The Power Of Ai And Knowledge Graphs" .
#
# :venue-37 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Symmetry" .
#
# :venue-38 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Digital Heritage. Progress In Cultural Heritage: Documentation, Preservation, And Protection - Lecture Notes In Computer Science" .
#
# :venue-39 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Digital Libraries For Open Knowledge - Lecture Notes In Computer Science" .
#
# :venue-4 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Disease Models & Mechanisms" .
#
# :venue-40 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes In Business Information Processing - Advanced Information Systems Engineering Workshops" .
#
# :venue-41 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Digital Innovation In The Built Environment" .
#
# :venue-42 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Mammalian Genome" .
#
# :venue-43 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes In Computer Science - Advances In Information Retrieval" .
#
# :venue-44 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "American Journal Of Medical Genetics Part A" .
#
# :venue-45 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Knowledge-Based Systems" .
#
# :venue-46 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Ambient Intelligence And Humanized Computing" .
#
# :venue-47 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Online Information Review" .
#
# :venue-48 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Ebiomedicine" .
#
# :venue-49 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes In Computer Science - The Semantic Web – Iswc 2019" .
#
# :venue-5 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Indoor And Built Environment" .
#
# :venue-50 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Strategic Information Technology And Applications" .
#
# :venue-51 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Transactions In Gis" .
#
# :venue-52 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Energies" .
#
# :venue-53 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Big Data & Society" .
#
# :venue-54 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Rules And Reasoning - Lecture Notes In Computer Science" .
#
# :venue-55 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Advances In Intelligent Systems And Computing - Trends And Applications In Information Systems And Technologies" .
#
# :venue-56 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Advances In Enterprise Engineering Xiii - Lecture Notes In Business Information Processing" .
#
# :venue-57 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Pervasive And Mobile Computing" .
#
# :venue-58 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Development" .
#
# :venue-59 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Information Retrieval Journal" .
#
# :venue-6 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Big Data And Cognitive Computing" .
#
# :venue-60 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Business Process Management Journal" .
#
# :venue-61 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Intelligent Manufacturing" .
#
# :venue-62 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Ai Approaches To The Complexity Of Legal Systems Xi-Xii - Lecture Notes In Computer Science" .
#
# :venue-63 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Research And Practice In Technology Enhanced Learning" .
#
# :venue-64 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Review Of Administrative Sciences" .
#
# :venue-65 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Sustainability Science" .
#
# :venue-66 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Journal Of Risk And Financial Management" .
#
# :venue-67 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Computers And Applications" .
#
# :venue-68 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Information" .
#
# :venue-69 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Technology Assessment In Health Care" .
#
# :venue-7 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Computers & Security" .
#
# :venue-70 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "The Scientific World Journal" .
#
# :venue-71 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Npj Digital Medicine" .
#
# :venue-72 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Pharmaceutical Research" .
#
# :venue-73 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Peerj Computer Science" .
#
# :venue-74 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Orphanet Journal Of Rare Diseases" .
#
# :venue-75 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Biomed Research International" .
#
# :venue-76 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Computer Graphics Forum" .
#
# :venue-77 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Ecological Informatics" .
#
# :venue-78 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Data Science" .
#
# :venue-79 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Robotics And Computer-Integrated Manufacturing" .
#
# :venue-8 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes In Computer Science - Artificial Intelligence Xxxvii" .
#
# :venue-80 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes In Management And Industrial Engineering - Organizational Engineering In Industry 4.0" .
#
# :venue-81 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Electronic Government Research" .
#
# :venue-82 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Safety Science" .
#
# :venue-83 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Biomolecules" .
#
# :venue-84 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Formal Aspects Of Computing" .
#
# :venue-85 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Environmental Research And Public Health" .
#
# :venue-86 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Designs" .
#
# :venue-87 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Applied Network Science" .
#
# :venue-88 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Lecture Notes In Computer Science - Description Logic, Theory Combination, And All That" .
#
# :venue-89 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Epidemiology" .
#
# :venue-9 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Measurement" .
#
# :venue-90 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Transinformação" .
#
# :venue-91 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Scientific Data" .
#
# :venue-92 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Axioms" .
#
# :venue-93 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "World Wide Web" .
#
# :venue-94 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "The Vldb Journal" .
#
# :venue-95 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Earth Science Informatics" .
#
# :venue-96 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Information And Communication Technologies In Education, Research, And Industrial Applications - Communications In Computer And Information Science" .
#
# :venue-97 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Forschung Im Ingenieurwesen" .
#
# :venue-98 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "Business Information Systems - Lecture Notes In Business Information Processing" .
#
# :venue-99 a <https://www.wikidata.org/wiki/Q2085381> ;
#     dcterms:title "International Journal Of Educational Technology In Higher Education" .
#
# fabio:BookChapter rdfs:subClassOf <https://www.wikidata.org/wiki/Q732577> .
#
# fabio:JournalArticle rdfs:subClassOf <https://www.wikidata.org/wiki/Q732577> .
